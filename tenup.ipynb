# %% [markdown]
# # 3.Ten'up - Selenium
#
# <img src = 'https://tenup.fft.fr/sites/all/themes/met/images/generic-img.png' >
#
#
# Dans ce projet, nous utiliserons la bibliothèque Selenium afin de collecter les données du site internet suivant :
#
# - [Ten'up](https://tenup.fft.fr//)
# Nous collecterons les données correspondants au tournois par rapport à une ville.
#
# Les informations que nous souhaitons collecter sont les suivantes :
# - le nom du tournois
# - la localisation
# - date de début
# - date de fin
# - catégorie des participant
# - la disctance par rapport au point de recherche
# - le point de recherche
# - la date et l'heure de la recherche

# %% [markdown]
# ## 1.1 Configuration de venv

# %%
# !python3 -m venv env .\venv # commande pour mettre en place un env virtuel en python
# !source env/Scripts/activate # commande pour activer un env virtuel en python
# deactivate # command to stop the virtual environment
# pip install -r requirements.txt # commande pour installer toute les dépandances necessaire pour le projet

# %% [markdown]
# ## 1.2 Installez la bibliothèque Selenium

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (4.5.0)
# Requirement already satisfied: trio~=0.17 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from selenium) (1.26.8)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (1.0.0rc9)
# Requirement already satisfied: idna in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: sniffio in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: outcome in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# ## 1.3 Installez la bibliothèque webdriver-manager

# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (3.8.4)
# Requirement already satisfied: python-dotenv in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: requests in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from webdriver-manager) (2.27.1)
# Requirement already satisfied: tqdm in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from webdriver-manager) (4.63.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from requests->webdriver-manager) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from requests->webdriver-manager) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: colorama in c:\users\max\scoop\apps\miniconda3\4.12.0\lib\site-packages (from tqdm->webdriver-manager) (0.4.4)

# %% [markdown]
# ## 2.1 Importer la bibliothèque selenium

# %%
from selenium import webdriver

# %% [markdown]
# ## 2.2 Importer l'objet `webdriver` de la bibliothèque de `selenium`

# %%
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ## 2.3 Importer la bibliothèque webdriver_manager

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## 2.4 Initialiser l'url
# `BASE_URL` est le lien pointant vers la recherche de tournois du site `Ten'up` `"https://tenup.fft.fr/recherche/tournois"`

# %%
BASE_URL = "https://tenup.fft.fr/recherche/tournois"

# %% [markdown]
# ## 2.5 Deffinir les options pour webdriver

# %%
chrome_options = Options
chrome_options.add_experimental_option("detach", True)

# %%
driver = Chrome(service=Service(ChromeDriverManager().install()),
                options=chrome_options)

# %% [markdown]
# ## 3.1 Acceder à l'url

# %% [markdown]
# driver.get(BASE_URL)

# %% [markdown]
# ## 3.2 Affichez l'adresse url courante ainsi que le titre de la page.

# %%
driver.current_url

# %%
driver.title
